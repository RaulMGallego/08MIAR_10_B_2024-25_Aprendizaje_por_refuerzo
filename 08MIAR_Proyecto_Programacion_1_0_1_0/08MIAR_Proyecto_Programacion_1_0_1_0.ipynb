# %% [markdown]
# # Actividad - Proyecto práctico
#
#
# > La actividad se desarrollará en grupos pre-definidos de 2-3 alumnos. Se debe indicar los nombres en orden alfabético (de apellidos). Recordad que esta actividad se corresponde con un 30% de la nota final de la asignatura. Se debe entregar entregar el trabajo en la presente notebook.
# *   Alumno 1: Marta Castillo Galán
# *   Alumno 2: Unai Marín Etxebarria
# *   Alumno 3: Laura Molinos Mayo
# *   Alumno 4: Raúl Murillo Gallego

# %% [markdown]
# ---
# ## **PARTE 2**. Enunciado
#
# Consideraciones a tener en cuenta:
#
# - El entorno sobre el que trabajaremos será _SpaceInvaders-v0_ y el algoritmo que usaremos será _DQN_.
#
# - Para nuestro ejercicio, el requisito mínimo será alcanzado cuando el agente consiga una **media de recompensa por encima de 20 puntos en modo test**. Por ello, esta media de la recompensa se calculará a partir del código de test en la última celda del notebook.
#
# Este proyecto práctico consta de tres partes:
#
# 1.   Implementar la red neuronal que se usará en la solución
# 2.   Implementar las distintas piezas de la solución DQN
# 3.   Justificar la respuesta en relación a los resultados obtenidos
#
# **Rúbrica**: Se valorará la originalidad en la solución aportada, así como la capacidad de discutir los resultados de forma detallada. El requisito mínimo servirá para aprobar la actividad, bajo premisa de que la discusión del resultado sera apropiada.
#
# IMPORTANTE:
#
# * Si no se consigue una puntuación óptima, responder sobre la mejor puntuación obtenida.
# * Para entrenamientos largos, recordad que podéis usar checkpoints de vuestros modelos para retomar los entrenamientos. En este caso, recordad cambiar los parámetros adecuadamente (sobre todo los relacionados con el proceso de exploración).
# * Se deberá entregar unicamente el notebook y los pesos del mejor modelo en un fichero .zip, de forma organizada.
# * Cada alumno deberá de subir la solución de forma individual.

# %% [markdown]
# ---
# ## **PARTE 3**. Desarrollo y preguntas

# %% [markdown]
# #### Importar librerías

# %%
from __future__ import division

from PIL import Image
import numpy as np
import gym

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Activation, Flatten, Convolution2D, Permute, BatchNormalization, Dropout
from tensorflow.keras.optimizers import Adam
import tensorflow.keras.backend as K

from rl.agents.dqn import DQNAgent
from rl.policy import LinearAnnealedPolicy, BoltzmannQPolicy, EpsGreedyQPolicy
from rl.memory import SequentialMemory
from rl.core import Processor
from rl.callbacks import FileLogger, ModelIntervalCheckpoint

from tensorflow.keras.optimizers import RMSprop
import matplotlib.pyplot as plt

# %% [markdown]
# #### Configuración base

# %%
INPUT_SHAPE = (84, 84)
WINDOW_LENGTH = 4

env_name = 'SpaceInvaders-v0'
env = gym.make(env_name)

np.random.seed(123)
env.seed(123)
nb_actions = env.action_space.n

# %%
class AtariProcessor(Processor):
    def process_observation(self, observation):
        assert observation.ndim == 3  # (height, width, channel)
        img = Image.fromarray(observation)
        img = img.resize(INPUT_SHAPE).convert('L')
        processed_observation = np.array(img)
        assert processed_observation.shape == INPUT_SHAPE
        return processed_observation.astype('uint8')

    def process_state_batch(self, batch):
        processed_batch = batch.astype('float32') / 255.
        return processed_batch

    def process_reward(self, reward):
        return np.clip(reward, -1., 1.)

# %% [markdown]
# 1. Implementación de la red neuronal

# %%
def build_model(window_length, input_shape, nb_actions):
    model = Sequential()
    model.add(Permute((2, 3, 1), input_shape=(window_length,) + input_shape))  # (window, 84, 84) → (84, 84, window)
    model.add(Convolution2D(32, (8, 8), strides=(4, 4), activation='relu'))
    model.add(Convolution2D(64, (4, 4), strides=(2, 2), activation='relu'))
    model.add(Convolution2D(128, (3, 3), strides=(1, 1), activation='relu'))
    model.add(Flatten())
    model.add(Dense(128, activation='relu'))
    model.add(Dense(nb_actions, activation='linear'))
    return model

# %% [markdown]
# 2. Implementación de la solución DQN

# %%
# Preparamos memoria y política
memory = SequentialMemory(limit=1_000_000, window_length=WINDOW_LENGTH)
policy = LinearAnnealedPolicy(EpsGreedyQPolicy(),
                              attr='eps',
                              value_max=1.0,
                              value_min=0.1,
                              value_test=0.05,
                              nb_steps=2_000_000) 

# Creamos el modelo
model = build_model(WINDOW_LENGTH, INPUT_SHAPE, nb_actions)
print(model.summary())

# Creamos el procesador
processor = AtariProcessor()

#Creamos el agente
dqn = DQNAgent(model=model,
               nb_actions=nb_actions,
               policy=policy,
               memory=memory,
               processor=processor,
               nb_steps_warmup=50_000,
               gamma=0.99,
               train_interval=4,
               target_model_update=10_000,
               delta_clip=1.0,
               enable_dueling_network=True, 
               dueling_type='avg'
               )

dqn.compile(Adam(learning_rate=0.00025), metrics=['mae'])
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# permute (Permute)            (None, 84, 84, 4)         0
# _________________________________________________________________
# conv2d (Conv2D)              (None, 20, 20, 32)        8224
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 9, 9, 64)          32832
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 7, 7, 128)         73856
# _________________________________________________________________
# flatten (Flatten)            (None, 6272)              0
# _________________________________________________________________
# dense (Dense)                (None, 128)               802944
# _________________________________________________________________
# dense_1 (Dense)              (None, 6)                 774
# =================================================================
# Total params: 918,630
# Trainable params: 918,630
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
weights_filename = 'dqn_{}_weights.h5f'.format(env_name)
checkpoint_weights_filename = 'dqn_' + env_name + '_weights_{step}.h5f'
callbacks = [ModelIntervalCheckpoint(checkpoint_weights_filename, interval=100_000)]

# %%
history=dqn.fit(env, nb_steps=5_000_000, callbacks=callbacks, visualize=False, verbose=1)
# Out:
# Training for 5000000 steps ...
# Interval 1 (0 steps performed)
#     1/10000 [..............................] - ETA: 27:06 - reward: 0.0000e+00
# C:\Users\laura\anaconda3\envs\miar_rl\lib\site-packages\tensorflow\python\keras\engine\training.py:2426: UserWarning: `Model.state_updates` will be removed in a future version. This property should not be used in TensorFlow 2.0, as `updates` are applied automatically.
#   warnings.warn('`Model.state_updates` will be removed in a future version. '
# 10000/10000 [==============================] - 40s 4ms/step - reward: 0.0124
# 16 episodes - episode_reward: 7.375 [4.000, 12.000] - ale.lives: 2.217
#
# Interval 2 (10000 steps performed)
# 10000/10000 [==============================] - 43s 4ms/step - reward: 0.0144
# 13 episodes - episode_reward: 10.615 [4.000, 22.000] - ale.lives: 2.029
#
# Interval 3 (20000 steps performed)
# 10000/10000 [==============================] - 44s 4ms/step - reward: 0.0148
# 16 episodes - episode_reward: 9.625 [4.000, 22.000] - ale.lives: 2.123
#
# Interval 4 (30000 steps performed)
# 10000/10000 [==============================] - 53s 5ms/step - reward: 0.0138
# 15 episodes - episode_reward: 9.467 [3.000, 27.000] - ale.lives: 2.080
#
# Interval 5 (40000 steps performed)
# 10000/10000 [==============================] - 41s 4ms/step - reward: 0.0159
# 15 episodes - episode_reward: 10.600 [2.000, 31.000] - ale.lives: 2.104
#
# Interval 6 (50000 steps performed)
# 10000/10000 [==============================] - 294s 29ms/step - reward: 0.0143
# 16 episodes - episode_reward: 8.875 [3.000, 21.000] - loss: 0.007 - mae: 0.032 - mean_q: 0.040 - mean_eps: 0.975 - ale.lives: 2.169
#
# Interval 7 (60000 steps performed)
# 10000/10000 [==============================] - 292s 29ms/step - reward: 0.0137
# 14 episodes - episode_reward: 9.571 [4.000, 16.000] - loss: 0.007 - mae: 0.051 - mean_q: 0.063 - mean_eps: 0.971 - ale.lives: 2.014
#
# Interval 8 (70000 steps performed)
# 10000/10000 [==============================] - 298s 30ms/step - reward: 0.0133
# 12 episodes - episode_reward: 11.417 [2.000, 22.000] - loss: 0.007 - mae: 0.067 - mean_q: 0.084 - mean_eps: 0.966 - ale.lives: 2.088
#
# Interval 9 (80000 steps performed)
# 10000/10000 [==============================] - 301s 30ms/step - reward: 0.0145
# 13 episodes - episode_reward: 10.846 [5.000, 19.000] - loss: 0.007 - mae: 0.088 - mean_q: 0.112 - mean_eps: 0.962 - ale.lives: 2.094
#
# Interval 10 (90000 steps performed)
# 10000/10000 [==============================] - 303s 30ms/step - reward: 0.0133
# 13 episodes - episode_reward: 10.308 [4.000, 26.000] - loss: 0.006 - mae: 0.114 - mean_q: 0.143 - mean_eps: 0.957 - ale.lives: 2.170
#
# Interval 11 (100000 steps performed)
# 10000/10000 [==============================] - 304s 30ms/step - reward: 0.0159
# 13 episodes - episode_reward: 10.692 [4.000, 24.000] - loss: 0.007 - mae: 0.142 - mean_q: 0.177 - mean_eps: 0.953 - ale.lives: 2.216
#
# Interval 12 (110000 steps performed)
# 10000/10000 [==============================] - 303s 30ms/step - reward: 0.0126
# 17 episodes - episode_reward: 8.765 [4.000, 30.000] - loss: 0.007 - mae: 0.161 - mean_q: 0.201 - mean_eps: 0.948 - ale.lives: 2.120
#
# Interval 13 (120000 steps performed)
# 10000/10000 [==============================] - 305s 31ms/step - reward: 0.0132
# 14 episodes - episode_reward: 9.500 [6.000, 17.000] - loss: 0.007 - mae: 0.184 - mean_q: 0.229 - mean_eps: 0.944 - ale.lives: 2.099
#
# Interval 14 (130000 steps performed)
# 10000/10000 [==============================] - 310s 31ms/step - reward: 0.0146
# 14 episodes - episode_reward: 10.429 [3.000, 28.000] - loss: 0.007 - mae: 0.210 - mean_q: 0.260 - mean_eps: 0.939 - ale.lives: 2.062
#
# Interval 15 (140000 steps performed)
# 10000/10000 [==============================] - 304s 30ms/step - reward: 0.0142
# 16 episodes - episode_reward: 8.500 [3.000, 17.000] - loss: 0.007 - mae: 0.242 - mean_q: 0.299 - mean_eps: 0.935 - ale.lives: 2.167
#
# Interval 16 (150000 steps performed)
# 10000/10000 [==============================] - 306s 31ms/step - reward: 0.0138
# 16 episodes - episode_reward: 8.562 [2.000, 15.000] - loss: 0.007 - mae: 0.251 - mean_q: 0.310 - mean_eps: 0.930 - ale.lives: 2.124
#
# Interval 17 (160000 steps performed)
# 10000/10000 [==============================] - 306s 31ms/step - reward: 0.0126
# 16 episodes - episode_reward: 8.000 [3.000, 12.000] - loss: 0.007 - mae: 0.278 - mean_q: 0.343 - mean_eps: 0.926 - ale.lives: 1.976
#
# Interval 18 (170000 steps performed)
# 10000/10000 [==============================] - 312s 31ms/step - reward: 0.0133
# 16 episodes - episode_reward: 8.688 [4.000, 17.000] - loss: 0.008 - mae: 0.298 - mean_q: 0.367 - mean_eps: 0.921 - ale.lives: 2.102
#
# Interval 19 (180000 steps performed)
# 10000/10000 [==============================] - 309s 31ms/step - reward: 0.0138
# 14 episodes - episode_reward: 9.286 [4.000, 21.000] - loss: 0.008 - mae: 0.324 - mean_q: 0.398 - mean_eps: 0.917 - ale.lives: 2.151
#
# Interval 20 (190000 steps performed)
# 10000/10000 [==============================] - 317s 32ms/step - reward: 0.0138
# 16 episodes - episode_reward: 9.125 [3.000, 16.000] - loss: 0.008 - mae: 0.341 - mean_q: 0.419 - mean_eps: 0.912 - ale.lives: 2.209
#
# Interval 21 (200000 steps performed)
# 10000/10000 [==============================] - 315s 31ms/step - reward: 0.0122
# 17 episodes - episode_reward: 6.765 [2.000, 11.000] - loss: 0.008 - mae: 0.355 - mean_q: 0.436 - mean_eps: 0.908 - ale.lives: 2.167
#
# Interval 22 (210000 steps performed)
# 10000/10000 [==============================] - 314s 31ms/step - reward: 0.0134
# 14 episodes - episode_reward: 9.714 [3.000, 16.000] - loss: 0.008 - mae: 0.387 - mean_q: 0.474 - mean_eps: 0.903 - ale.lives: 2.159
#
# Interval 23 (220000 steps performed)
# 10000/10000 [==============================] - 319s 32ms/step - reward: 0.0138
# 14 episodes - episode_reward: 9.857 [3.000, 21.000] - loss: 0.008 - mae: 0.408 - mean_q: 0.501 - mean_eps: 0.899 - ale.lives: 2.226
#
# Interval 24 (230000 steps performed)
# 10000/10000 [==============================] - 320s 32ms/step - reward: 0.0147
# 13 episodes - episode_reward: 11.231 [4.000, 21.000] - loss: 0.008 - mae: 0.434 - mean_q: 0.532 - mean_eps: 0.894 - ale.lives: 2.030
#
# Interval 25 (240000 steps performed)
# 10000/10000 [==============================] - 324s 32ms/step - reward: 0.0153
# 18 episodes - episode_reward: 8.500 [5.000, 15.000] - loss: 0.008 - mae: 0.443 - mean_q: 0.543 - mean_eps: 0.890 - ale.lives: 2.050
#
# Interval 26 (250000 steps performed)
# 10000/10000 [==============================] - 323s 32ms/step - reward: 0.0149
# 13 episodes - episode_reward: 11.769 [6.000, 21.000] - loss: 0.009 - mae: 0.481 - mean_q: 0.590 - mean_eps: 0.885 - ale.lives: 2.136
#
# Interval 27 (260000 steps performed)
# 10000/10000 [==============================] - 326s 33ms/step - reward: 0.0151
# 17 episodes - episode_reward: 8.824 [5.000, 14.000] - loss: 0.009 - mae: 0.507 - mean_q: 0.622 - mean_eps: 0.881 - ale.lives: 1.964
#
# Interval 28 (270000 steps performed)
# 10000/10000 [==============================] - 323s 32ms/step - reward: 0.0149
# 15 episodes - episode_reward: 9.667 [4.000, 22.000] - loss: 0.009 - mae: 0.533 - mean_q: 0.651 - mean_eps: 0.876 - ale.lives: 2.128
#
# Interval 29 (280000 steps performed)
# 10000/10000 [==============================] - 327s 33ms/step - reward: 0.0152
# 16 episodes - episode_reward: 9.875 [4.000, 20.000] - loss: 0.009 - mae: 0.553 - mean_q: 0.675 - mean_eps: 0.872 - ale.lives: 2.172
#
# Interval 30 (290000 steps performed)
# 10000/10000 [==============================] - 326s 33ms/step - reward: 0.0141
# 14 episodes - episode_reward: 9.214 [4.000, 16.000] - loss: 0.010 - mae: 0.592 - mean_q: 0.723 - mean_eps: 0.867 - ale.lives: 2.174
#
# Interval 31 (300000 steps performed)
# 10000/10000 [==============================] - 336s 34ms/step - reward: 0.0156
# 15 episodes - episode_reward: 11.067 [6.000, 15.000] - loss: 0.010 - mae: 0.620 - mean_q: 0.758 - mean_eps: 0.863 - ale.lives: 2.192
#
# Interval 32 (310000 steps performed)
# 10000/10000 [==============================] - 334s 33ms/step - reward: 0.0166
# 13 episodes - episode_reward: 12.154 [6.000, 22.000] - loss: 0.010 - mae: 0.649 - mean_q: 0.793 - mean_eps: 0.858 - ale.lives: 2.151
#
# Interval 33 (320000 steps performed)
# 10000/10000 [==============================] - 342s 34ms/step - reward: 0.0144
# 16 episodes - episode_reward: 9.562 [4.000, 16.000] - loss: 0.010 - mae: 0.682 - mean_q: 0.834 - mean_eps: 0.854 - ale.lives: 2.133
#
# Interval 34 (330000 steps performed)
# 10000/10000 [==============================] - 338s 34ms/step - reward: 0.0145
# 14 episodes - episode_reward: 10.214 [3.000, 18.000] - loss: 0.010 - mae: 0.700 - mean_q: 0.856 - mean_eps: 0.849 - ale.lives: 2.085
#
# Interval 35 (340000 steps performed)
# 10000/10000 [==============================] - 336s 34ms/step - reward: 0.0149
# 16 episodes - episode_reward: 9.000 [4.000, 14.000] - loss: 0.011 - mae: 0.724 - mean_q: 0.885 - mean_eps: 0.845 - ale.lives: 2.109
#
# Interval 36 (350000 steps performed)
# 10000/10000 [==============================] - 348s 35ms/step - reward: 0.0157
# 15 episodes - episode_reward: 11.000 [5.000, 18.000] - loss: 0.011 - mae: 0.754 - mean_q: 0.921 - mean_eps: 0.840 - ale.lives: 2.129
#
# Interval 37 (360000 steps performed)
# 10000/10000 [==============================] - 347s 35ms/step - reward: 0.0174
# 14 episodes - episode_reward: 10.857 [4.000, 19.000] - loss: 0.011 - mae: 0.773 - mean_q: 0.945 - mean_eps: 0.836 - ale.lives: 2.112
#
# Interval 38 (370000 steps performed)
# 10000/10000 [==============================] - 346s 35ms/step - reward: 0.0161
# 14 episodes - episode_reward: 12.643 [6.000, 24.000] - loss: 0.011 - mae: 0.803 - mean_q: 0.980 - mean_eps: 0.831 - ale.lives: 1.998
#
# Interval 39 (380000 steps performed)
# 10000/10000 [==============================] - 346s 35ms/step - reward: 0.0152
# 16 episodes - episode_reward: 9.562 [5.000, 22.000] - loss: 0.012 - mae: 0.842 - mean_q: 1.026 - mean_eps: 0.827 - ale.lives: 2.192
#
# Interval 40 (390000 steps performed)
# 10000/10000 [==============================] - 348s 35ms/step - reward: 0.0165
# 15 episodes - episode_reward: 11.267 [9.000, 15.000] - loss: 0.011 - mae: 0.861 - mean_q: 1.050 - mean_eps: 0.822 - ale.lives: 2.058
#
# Interval 41 (400000 steps performed)
# 10000/10000 [==============================] - 349s 35ms/step - reward: 0.0167
# 15 episodes - episode_reward: 10.933 [6.000, 18.000] - loss: 0.012 - mae: 0.900 - mean_q: 1.095 - mean_eps: 0.818 - ale.lives: 2.251
#
# Interval 42 (410000 steps performed)
# 10000/10000 [==============================] - 356s 36ms/step - reward: 0.0172
# 15 episodes - episode_reward: 11.333 [6.000, 21.000] - loss: 0.012 - mae: 0.930 - mean_q: 1.132 - mean_eps: 0.813 - ale.lives: 2.116
#
# Interval 43 (420000 steps performed)
# 10000/10000 [==============================] - 351s 35ms/step - reward: 0.0153
# 16 episodes - episode_reward: 9.562 [3.000, 22.000] - loss: 0.012 - mae: 0.964 - mean_q: 1.173 - mean_eps: 0.809 - ale.lives: 2.061
#
# Interval 44 (430000 steps performed)
# 10000/10000 [==============================] - 354s 35ms/step - reward: 0.0159
# 14 episodes - episode_reward: 11.643 [4.000, 26.000] - loss: 0.012 - mae: 0.986 - mean_q: 1.200 - mean_eps: 0.804 - ale.lives: 2.208
#
# Interval 45 (440000 steps performed)
# 10000/10000 [==============================] - 358s 36ms/step - reward: 0.0172
# 14 episodes - episode_reward: 11.929 [7.000, 21.000] - loss: 0.012 - mae: 1.011 - mean_q: 1.229 - mean_eps: 0.800 - ale.lives: 2.080
#
# Interval 46 (450000 steps performed)
# 10000/10000 [==============================] - 363s 36ms/step - reward: 0.0176
# 13 episodes - episode_reward: 13.077 [5.000, 24.000] - loss: 0.012 - mae: 1.029 - mean_q: 1.250 - mean_eps: 0.795 - ale.lives: 2.081
#
# Interval 47 (460000 steps performed)
# 10000/10000 [==============================] - 362s 36ms/step - reward: 0.0169
# 14 episodes - episode_reward: 12.643 [7.000, 18.000] - loss: 0.013 - mae: 1.074 - mean_q: 1.305 - mean_eps: 0.791 - ale.lives: 2.026
#
# Interval 48 (470000 steps performed)
# 10000/10000 [==============================] - 365s 36ms/step - reward: 0.0173
# 14 episodes - episode_reward: 12.786 [6.000, 32.000] - loss: 0.013 - mae: 1.098 - mean_q: 1.332 - mean_eps: 0.786 - ale.lives: 2.117
#
# Interval 49 (480000 steps performed)
# 10000/10000 [==============================] - 365s 37ms/step - reward: 0.0173
# 15 episodes - episode_reward: 10.867 [5.000, 17.000] - loss: 0.013 - mae: 1.101 - mean_q: 1.337 - mean_eps: 0.782 - ale.lives: 2.150
#
# Interval 50 (490000 steps performed)
# 10000/10000 [==============================] - 370s 37ms/step - reward: 0.0167
# 15 episodes - episode_reward: 11.200 [4.000, 22.000] - loss: 0.013 - mae: 1.125 - mean_q: 1.364 - mean_eps: 0.777 - ale.lives: 2.141
#
# Interval 51 (500000 steps performed)
# 10000/10000 [==============================] - 375s 37ms/step - reward: 0.0161
# 14 episodes - episode_reward: 11.429 [7.000, 30.000] - loss: 0.013 - mae: 1.165 - mean_q: 1.413 - mean_eps: 0.773 - ale.lives: 2.214
#
# Interval 52 (510000 steps performed)
# 10000/10000 [==============================] - 378s 38ms/step - reward: 0.0167
# 15 episodes - episode_reward: 11.733 [5.000, 19.000] - loss: 0.013 - mae: 1.192 - mean_q: 1.445 - mean_eps: 0.768 - ale.lives: 2.195
#
# Interval 53 (520000 steps performed)
# 10000/10000 [==============================] - 380s 38ms/step - reward: 0.0180
# 16 episodes - episode_reward: 11.312 [8.000, 22.000] - loss: 0.014 - mae: 1.218 - mean_q: 1.475 - mean_eps: 0.764 - ale.lives: 2.069
#
# Interval 54 (530000 steps performed)
# 10000/10000 [==============================] - 388s 39ms/step - reward: 0.0175
# 13 episodes - episode_reward: 11.231 [6.000, 22.000] - loss: 0.014 - mae: 1.242 - mean_q: 1.503 - mean_eps: 0.759 - ale.lives: 2.170
#
# Interval 55 (540000 steps performed)
# 10000/10000 [==============================] - 385s 38ms/step - reward: 0.0167
# 12 episodes - episode_reward: 15.833 [7.000, 29.000] - loss: 0.014 - mae: 1.259 - mean_q: 1.524 - mean_eps: 0.755 - ale.lives: 2.095
#
# Interval 56 (550000 steps performed)
# 10000/10000 [==============================] - 390s 39ms/step - reward: 0.0196
# 13 episodes - episode_reward: 14.462 [8.000, 24.000] - loss: 0.014 - mae: 1.284 - mean_q: 1.554 - mean_eps: 0.750 - ale.lives: 2.086
#
# Interval 57 (560000 steps performed)
# 10000/10000 [==============================] - 395s 39ms/step - reward: 0.0164
# 15 episodes - episode_reward: 11.200 [4.000, 20.000] - loss: 0.014 - mae: 1.326 - mean_q: 1.604 - mean_eps: 0.746 - ale.lives: 2.201
#
# Interval 58 (570000 steps performed)
# 10000/10000 [==============================] - 394s 39ms/step - reward: 0.0175
# 15 episodes - episode_reward: 11.867 [6.000, 20.000] - loss: 0.014 - mae: 1.357 - mean_q: 1.641 - mean_eps: 0.741 - ale.lives: 2.094
#
# Interval 59 (580000 steps performed)
# 10000/10000 [==============================] - 404s 40ms/step - reward: 0.0178
# 15 episodes - episode_reward: 11.733 [3.000, 24.000] - loss: 0.015 - mae: 1.376 - mean_q: 1.663 - mean_eps: 0.737 - ale.lives: 2.178
#
# Interval 60 (590000 steps performed)
# 10000/10000 [==============================] - 406s 41ms/step - reward: 0.0162
# 15 episodes - episode_reward: 10.533 [5.000, 18.000] - loss: 0.015 - mae: 1.402 - mean_q: 1.695 - mean_eps: 0.732 - ale.lives: 2.137
#
# Interval 61 (600000 steps performed)
# 10000/10000 [==============================] - 407s 41ms/step - reward: 0.0184
# 14 episodes - episode_reward: 13.786 [6.000, 23.000] - loss: 0.015 - mae: 1.439 - mean_q: 1.737 - mean_eps: 0.728 - ale.lives: 2.000
#
# Interval 62 (610000 steps performed)
# 10000/10000 [==============================] - 412s 41ms/step - reward: 0.0198
# 13 episodes - episode_reward: 14.385 [5.000, 29.000] - loss: 0.015 - mae: 1.478 - mean_q: 1.783 - mean_eps: 0.723 - ale.lives: 2.008
#
# Interval 63 (620000 steps performed)
# 10000/10000 [==============================] - 417s 42ms/step - reward: 0.0182
# 13 episodes - episode_reward: 15.154 [7.000, 24.000] - loss: 0.015 - mae: 1.508 - mean_q: 1.819 - mean_eps: 0.719 - ale.lives: 2.070
#
# Interval 64 (630000 steps performed)
# 10000/10000 [==============================] - 414s 41ms/step - reward: 0.0193
# 12 episodes - episode_reward: 14.750 [2.000, 28.000] - loss: 0.016 - mae: 1.562 - mean_q: 1.884 - mean_eps: 0.714 - ale.lives: 2.085
#
# Interval 65 (640000 steps performed)
# 10000/10000 [==============================] - 426s 43ms/step - reward: 0.0179
# 15 episodes - episode_reward: 13.000 [4.000, 31.000] - loss: 0.016 - mae: 1.589 - mean_q: 1.917 - mean_eps: 0.710 - ale.lives: 2.145
#
# Interval 66 (650000 steps performed)
# 10000/10000 [==============================] - 426s 43ms/step - reward: 0.0183
# 17 episodes - episode_reward: 10.176 [6.000, 20.000] - loss: 0.015 - mae: 1.608 - mean_q: 1.941 - mean_eps: 0.705 - ale.lives: 2.099
#
# Interval 67 (660000 steps performed)
# 10000/10000 [==============================] - 426s 43ms/step - reward: 0.0160
# 17 episodes - episode_reward: 9.588 [5.000, 17.000] - loss: 0.016 - mae: 1.634 - mean_q: 1.971 - mean_eps: 0.701 - ale.lives: 2.034
#
# Interval 68 (670000 steps performed)
# 10000/10000 [==============================] - 440s 44ms/step - reward: 0.0163
# 17 episodes - episode_reward: 9.294 [4.000, 17.000] - loss: 0.015 - mae: 1.654 - mean_q: 1.997 - mean_eps: 0.696 - ale.lives: 2.162
#
# Interval 69 (680000 steps performed)
# 10000/10000 [==============================] - 441s 44ms/step - reward: 0.0176
# 15 episodes - episode_reward: 11.733 [5.000, 20.000] - loss: 0.015 - mae: 1.682 - mean_q: 2.029 - mean_eps: 0.692 - ale.lives: 2.106
#
# Interval 70 (690000 steps performed)
# 10000/10000 [==============================] - 449s 45ms/step - reward: 0.0189
# 14 episodes - episode_reward: 13.286 [5.000, 21.000] - loss: 0.016 - mae: 1.704 - mean_q: 2.053 - mean_eps: 0.687 - ale.lives: 2.082
#
# Interval 71 (700000 steps performed)
# 10000/10000 [==============================] - 450s 45ms/step - reward: 0.0183
# 14 episodes - episode_reward: 13.929 [6.000, 27.000] - loss: 0.015 - mae: 1.703 - mean_q: 2.053 - mean_eps: 0.683 - ale.lives: 2.076
#
# Interval 72 (710000 steps performed)
# 10000/10000 [==============================] - 452s 45ms/step - reward: 0.0183
# 14 episodes - episode_reward: 12.071 [5.000, 25.000] - loss: 0.015 - mae: 1.707 - mean_q: 2.058 - mean_eps: 0.678 - ale.lives: 1.951
#
# Interval 73 (720000 steps performed)
# 10000/10000 [==============================] - 465s 46ms/step - reward: 0.0189
# 14 episodes - episode_reward: 13.929 [5.000, 27.000] - loss: 0.016 - mae: 1.725 - mean_q: 2.080 - mean_eps: 0.674 - ale.lives: 2.238
#
# Interval 74 (730000 steps performed)
# 10000/10000 [==============================] - 485s 49ms/step - reward: 0.0182
# 14 episodes - episode_reward: 13.214 [3.000, 21.000] - loss: 0.016 - mae: 1.744 - mean_q: 2.104 - mean_eps: 0.669 - ale.lives: 2.020
#
# Interval 75 (740000 steps performed)
# 10000/10000 [==============================] - 481s 48ms/step - reward: 0.0181
# 14 episodes - episode_reward: 13.071 [8.000, 24.000] - loss: 0.016 - mae: 1.752 - mean_q: 2.112 - mean_eps: 0.665 - ale.lives: 2.232
#
# Interval 76 (750000 steps performed)
# 10000/10000 [==============================] - 479s 48ms/step - reward: 0.0209
# 13 episodes - episode_reward: 15.615 [7.000, 25.000] - loss: 0.016 - mae: 1.768 - mean_q: 2.132 - mean_eps: 0.660 - ale.lives: 2.058
#
# Interval 77 (760000 steps performed)
# 10000/10000 [==============================] - 481s 48ms/step - reward: 0.0186
# 13 episodes - episode_reward: 13.692 [5.000, 25.000] - loss: 0.016 - mae: 1.760 - mean_q: 2.121 - mean_eps: 0.656 - ale.lives: 1.975
#
# Interval 78 (770000 steps performed)
# 10000/10000 [==============================] - 487s 49ms/step - reward: 0.0190
# 14 episodes - episode_reward: 14.429 [2.000, 29.000] - loss: 0.016 - mae: 1.772 - mean_q: 2.134 - mean_eps: 0.651 - ale.lives: 2.164
#
# Interval 79 (780000 steps performed)
# 10000/10000 [==============================] - 489s 49ms/step - reward: 0.0211
# 11 episodes - episode_reward: 17.909 [9.000, 24.000] - loss: 0.015 - mae: 1.803 - mean_q: 2.171 - mean_eps: 0.647 - ale.lives: 2.152
#
# Interval 80 (790000 steps performed)
# 10000/10000 [==============================] - 497s 50ms/step - reward: 0.0175
# 14 episodes - episode_reward: 13.500 [5.000, 23.000] - loss: 0.016 - mae: 1.859 - mean_q: 2.239 - mean_eps: 0.642 - ale.lives: 1.971
#
# Interval 81 (800000 steps performed)
# 10000/10000 [==============================] - 507s 51ms/step - reward: 0.0188
# 13 episodes - episode_reward: 13.308 [5.000, 25.000] - loss: 0.016 - mae: 1.861 - mean_q: 2.241 - mean_eps: 0.638 - ale.lives: 1.976
#
# Interval 82 (810000 steps performed)
# 10000/10000 [==============================] - 523s 52ms/step - reward: 0.0210
# 13 episodes - episode_reward: 16.385 [11.000, 23.000] - loss: 0.017 - mae: 1.893 - mean_q: 2.280 - mean_eps: 0.633 - ale.lives: 2.118
#
# Interval 83 (820000 steps performed)
# 10000/10000 [==============================] - 514s 51ms/step - reward: 0.0198
# 13 episodes - episode_reward: 15.692 [7.000, 25.000] - loss: 0.017 - mae: 1.921 - mean_q: 2.313 - mean_eps: 0.629 - ale.lives: 2.147
#
# Interval 84 (830000 steps performed)
# 10000/10000 [==============================] - 519s 52ms/step - reward: 0.0190
# 16 episodes - episode_reward: 12.375 [7.000, 22.000] - loss: 0.017 - mae: 1.947 - mean_q: 2.345 - mean_eps: 0.624 - ale.lives: 2.197
#
# Interval 85 (840000 steps performed)
# 10000/10000 [==============================] - 511s 51ms/step - reward: 0.0197
# 12 episodes - episode_reward: 14.833 [7.000, 29.000] - loss: 0.017 - mae: 1.989 - mean_q: 2.397 - mean_eps: 0.620 - ale.lives: 2.005
#
# Interval 86 (850000 steps performed)
# 10000/10000 [==============================] - 521s 52ms/step - reward: 0.0196
# 13 episodes - episode_reward: 16.231 [6.000, 33.000] - loss: 0.018 - mae: 2.020 - mean_q: 2.433 - mean_eps: 0.615 - ale.lives: 2.091
#
# Interval 87 (860000 steps performed)
# 10000/10000 [==============================] - 530s 53ms/step - reward: 0.0198
# 13 episodes - episode_reward: 15.769 [5.000, 30.000] - loss: 0.016 - mae: 2.040 - mean_q: 2.459 - mean_eps: 0.611 - ale.lives: 1.986
#
# Interval 88 (870000 steps performed)
# 10000/10000 [==============================] - 531s 53ms/step - reward: 0.0196
# 13 episodes - episode_reward: 14.615 [8.000, 26.000] - loss: 0.017 - mae: 2.056 - mean_q: 2.478 - mean_eps: 0.606 - ale.lives: 2.009
#
# Interval 89 (880000 steps performed)
# 10000/10000 [==============================] - 541s 54ms/step - reward: 0.0205
# 14 episodes - episode_reward: 14.714 [8.000, 24.000] - loss: 0.018 - mae: 2.091 - mean_q: 2.520 - mean_eps: 0.602 - ale.lives: 2.197
#
# Interval 90 (890000 steps performed)
# 10000/10000 [==============================] - 547s 55ms/step - reward: 0.0187
# 14 episodes - episode_reward: 13.214 [5.000, 26.000] - loss: 0.018 - mae: 2.117 - mean_q: 2.550 - mean_eps: 0.597 - ale.lives: 2.154
#
# Interval 91 (900000 steps performed)
# 10000/10000 [==============================] - 550s 55ms/step - reward: 0.0203
# 13 episodes - episode_reward: 16.231 [4.000, 29.000] - loss: 0.018 - mae: 2.103 - mean_q: 2.532 - mean_eps: 0.593 - ale.lives: 1.905
#
# Interval 92 (910000 steps performed)
# 10000/10000 [==============================] - 557s 56ms/step - reward: 0.0177
# 13 episodes - episode_reward: 13.462 [5.000, 22.000] - loss: 0.017 - mae: 2.124 - mean_q: 2.557 - mean_eps: 0.588 - ale.lives: 2.201
#
# Interval 93 (920000 steps performed)
# 10000/10000 [==============================] - 562s 56ms/step - reward: 0.0222
# 14 episodes - episode_reward: 15.714 [5.000, 23.000] - loss: 0.017 - mae: 2.141 - mean_q: 2.577 - mean_eps: 0.584 - ale.lives: 2.092
#
# Interval 94 (930000 steps performed)
# 10000/10000 [==============================] - 556s 56ms/step - reward: 0.0195
# 14 episodes - episode_reward: 14.071 [6.000, 21.000] - loss: 0.017 - mae: 2.150 - mean_q: 2.589 - mean_eps: 0.579 - ale.lives: 2.128
#
# Interval 95 (940000 steps performed)
# 10000/10000 [==============================] - 572s 57ms/step - reward: 0.0202
# 13 episodes - episode_reward: 15.462 [5.000, 29.000] - loss: 0.018 - mae: 2.189 - mean_q: 2.633 - mean_eps: 0.575 - ale.lives: 2.108
#
# Interval 96 (950000 steps performed)
# 10000/10000 [==============================] - 580s 58ms/step - reward: 0.0193
# 15 episodes - episode_reward: 12.333 [7.000, 20.000] - loss: 0.017 - mae: 2.192 - mean_q: 2.640 - mean_eps: 0.570 - ale.lives: 2.144
#
# Interval 97 (960000 steps performed)
# 10000/10000 [==============================] - 580s 58ms/step - reward: 0.0211
# 14 episodes - episode_reward: 15.214 [5.000, 25.000] - loss: 0.016 - mae: 2.213 - mean_q: 2.665 - mean_eps: 0.566 - ale.lives: 2.049
#
# Interval 98 (970000 steps performed)
# 10000/10000 [==============================] - 592s 59ms/step - reward: 0.0177
# 14 episodes - episode_reward: 13.357 [6.000, 34.000] - loss: 0.017 - mae: 2.229 - mean_q: 2.683 - mean_eps: 0.561 - ale.lives: 2.119
#
# Interval 99 (980000 steps performed)
# 10000/10000 [==============================] - 604s 60ms/step - reward: 0.0207
# 14 episodes - episode_reward: 14.571 [6.000, 27.000] - loss: 0.017 - mae: 2.238 - mean_q: 2.693 - mean_eps: 0.557 - ale.lives: 2.112
#
# Interval 100 (990000 steps performed)
# 10000/10000 [==============================] - 604s 60ms/step - reward: 0.0192
# 13 episodes - episode_reward: 14.385 [5.000, 28.000] - loss: 0.018 - mae: 2.263 - mean_q: 2.723 - mean_eps: 0.552 - ale.lives: 2.330
#
# Interval 101 (1000000 steps performed)
# 10000/10000 [==============================] - 617s 62ms/step - reward: 0.0181
# 14 episodes - episode_reward: 13.571 [4.000, 27.000] - loss: 0.017 - mae: 2.273 - mean_q: 2.734 - mean_eps: 0.548 - ale.lives: 2.235
#
# Interval 102 (1010000 steps performed)
# 10000/10000 [==============================] - 608s 61ms/step - reward: 0.0197
# 13 episodes - episode_reward: 14.077 [3.000, 25.000] - loss: 0.017 - mae: 2.275 - mean_q: 2.737 - mean_eps: 0.543 - ale.lives: 2.163
#
# Interval 103 (1020000 steps performed)
# 10000/10000 [==============================] - 605s 60ms/step - reward: 0.0179
# 16 episodes - episode_reward: 11.875 [4.000, 21.000] - loss: 0.017 - mae: 2.271 - mean_q: 2.731 - mean_eps: 0.539 - ale.lives: 2.084
#
# Interval 104 (1030000 steps performed)
# 10000/10000 [==============================] - 607s 61ms/step - reward: 0.0196
# 14 episodes - episode_reward: 13.500 [6.000, 20.000] - loss: 0.017 - mae: 2.259 - mean_q: 2.717 - mean_eps: 0.534 - ale.lives: 2.160
#
# Interval 105 (1040000 steps performed)
# 10000/10000 [==============================] - 613s 61ms/step - reward: 0.0197
# 14 episodes - episode_reward: 14.357 [8.000, 25.000] - loss: 0.017 - mae: 2.254 - mean_q: 2.711 - mean_eps: 0.530 - ale.lives: 2.056
#
# Interval 106 (1050000 steps performed)
# 10000/10000 [==============================] - 617s 62ms/step - reward: 0.0197
# 14 episodes - episode_reward: 13.643 [5.000, 22.000] - loss: 0.016 - mae: 2.293 - mean_q: 2.760 - mean_eps: 0.525 - ale.lives: 2.152
#
# Interval 107 (1060000 steps performed)
# 10000/10000 [==============================] - 621s 62ms/step - reward: 0.0210
# 13 episodes - episode_reward: 15.923 [9.000, 22.000] - loss: 0.017 - mae: 2.296 - mean_q: 2.764 - mean_eps: 0.521 - ale.lives: 2.057
#
# Interval 108 (1070000 steps performed)
# 10000/10000 [==============================] - 618s 62ms/step - reward: 0.0208
# 13 episodes - episode_reward: 16.538 [9.000, 23.000] - loss: 0.017 - mae: 2.317 - mean_q: 2.788 - mean_eps: 0.516 - ale.lives: 2.130
#
# Interval 109 (1080000 steps performed)
# 10000/10000 [==============================] - 609s 61ms/step - reward: 0.0190
# 14 episodes - episode_reward: 14.143 [5.000, 27.000] - loss: 0.017 - mae: 2.331 - mean_q: 2.805 - mean_eps: 0.512 - ale.lives: 1.972
#
# Interval 110 (1090000 steps performed)
# 10000/10000 [==============================] - 614s 61ms/step - reward: 0.0202
# 12 episodes - episode_reward: 15.917 [7.000, 26.000] - loss: 0.017 - mae: 2.371 - mean_q: 2.853 - mean_eps: 0.507 - ale.lives: 2.170
#
# Interval 111 (1100000 steps performed)
# 10000/10000 [==============================] - 619s 62ms/step - reward: 0.0211
# 12 episodes - episode_reward: 17.917 [8.000, 32.000] - loss: 0.018 - mae: 2.373 - mean_q: 2.854 - mean_eps: 0.503 - ale.lives: 2.062
#
# Interval 112 (1110000 steps performed)
# 10000/10000 [==============================] - 634s 63ms/step - reward: 0.0209
# 13 episodes - episode_reward: 16.231 [5.000, 25.000] - loss: 0.017 - mae: 2.381 - mean_q: 2.861 - mean_eps: 0.498 - ale.lives: 2.073
#
# Interval 113 (1120000 steps performed)
# 10000/10000 [==============================] - 632s 63ms/step - reward: 0.0205
# 12 episodes - episode_reward: 16.833 [8.000, 33.000] - loss: 0.018 - mae: 2.411 - mean_q: 2.900 - mean_eps: 0.494 - ale.lives: 2.006
#
# Interval 114 (1130000 steps performed)
# 10000/10000 [==============================] - 615s 62ms/step - reward: 0.0209
# 14 episodes - episode_reward: 15.143 [8.000, 26.000] - loss: 0.017 - mae: 2.410 - mean_q: 2.898 - mean_eps: 0.489 - ale.lives: 2.068
#
# Interval 115 (1140000 steps performed)
# 10000/10000 [==============================] - 623s 62ms/step - reward: 0.0212
# 14 episodes - episode_reward: 13.929 [8.000, 26.000] - loss: 0.017 - mae: 2.428 - mean_q: 2.922 - mean_eps: 0.485 - ale.lives: 2.083
#
# Interval 116 (1150000 steps performed)
# 10000/10000 [==============================] - 622s 62ms/step - reward: 0.0212
# 12 episodes - episode_reward: 18.667 [9.000, 33.000] - loss: 0.018 - mae: 2.441 - mean_q: 2.936 - mean_eps: 0.480 - ale.lives: 2.020
#
# Interval 117 (1160000 steps performed)
# 10000/10000 [==============================] - 625s 62ms/step - reward: 0.0207
# 13 episodes - episode_reward: 16.385 [7.000, 31.000] - loss: 0.018 - mae: 2.462 - mean_q: 2.961 - mean_eps: 0.476 - ale.lives: 2.098
#
# Interval 118 (1170000 steps performed)
# 10000/10000 [==============================] - 619s 62ms/step - reward: 0.0210
# 15 episodes - episode_reward: 14.267 [6.000, 27.000] - loss: 0.018 - mae: 2.485 - mean_q: 2.989 - mean_eps: 0.471 - ale.lives: 2.074
#
# Interval 119 (1180000 steps performed)
# 10000/10000 [==============================] - 601s 60ms/step - reward: 0.0211
# 13 episodes - episode_reward: 15.154 [7.000, 28.000] - loss: 0.018 - mae: 2.483 - mean_q: 2.988 - mean_eps: 0.467 - ale.lives: 2.225
#
# Interval 120 (1190000 steps performed)
# 10000/10000 [==============================] - 627s 63ms/step - reward: 0.0183
# 14 episodes - episode_reward: 14.071 [8.000, 24.000] - loss: 0.018 - mae: 2.494 - mean_q: 3.002 - mean_eps: 0.462 - ale.lives: 2.087
#
# Interval 121 (1200000 steps performed)
# 10000/10000 [==============================] - 611s 61ms/step - reward: 0.0213
# 13 episodes - episode_reward: 16.154 [9.000, 25.000] - loss: 0.018 - mae: 2.481 - mean_q: 2.987 - mean_eps: 0.458 - ale.lives: 2.212
#
# Interval 122 (1210000 steps performed)
# 10000/10000 [==============================] - 613s 61ms/step - reward: 0.0203
# 13 episodes - episode_reward: 15.000 [9.000, 26.000] - loss: 0.018 - mae: 2.516 - mean_q: 3.029 - mean_eps: 0.453 - ale.lives: 1.994
#
# Interval 123 (1220000 steps performed)
# 10000/10000 [==============================] - 620s 62ms/step - reward: 0.0208
# 13 episodes - episode_reward: 16.308 [6.000, 25.000] - loss: 0.018 - mae: 2.538 - mean_q: 3.054 - mean_eps: 0.449 - ale.lives: 2.159
#
# Interval 124 (1230000 steps performed)
# 10000/10000 [==============================] - 618s 62ms/step - reward: 0.0196
# 12 episodes - episode_reward: 16.500 [5.000, 29.000] - loss: 0.018 - mae: 2.561 - mean_q: 3.083 - mean_eps: 0.444 - ale.lives: 1.988
#
# Interval 125 (1240000 steps performed)
# 10000/10000 [==============================] - 621s 62ms/step - reward: 0.0184
# 13 episodes - episode_reward: 14.462 [6.000, 28.000] - loss: 0.019 - mae: 2.557 - mean_q: 3.075 - mean_eps: 0.440 - ale.lives: 2.103
#
# Interval 126 (1250000 steps performed)
# 10000/10000 [==============================] - 618s 62ms/step - reward: 0.0171
# 11 episodes - episode_reward: 14.636 [2.000, 35.000] - loss: 0.018 - mae: 2.568 - mean_q: 3.092 - mean_eps: 0.435 - ale.lives: 2.067
#
# Interval 127 (1260000 steps performed)
# 10000/10000 [==============================] - 631s 63ms/step - reward: 0.0194
# 13 episodes - episode_reward: 15.385 [5.000, 24.000] - loss: 0.019 - mae: 2.596 - mean_q: 3.125 - mean_eps: 0.431 - ale.lives: 2.075
#
# Interval 128 (1270000 steps performed)
# 10000/10000 [==============================] - 623s 62ms/step - reward: 0.0186
# 14 episodes - episode_reward: 13.214 [6.000, 30.000] - loss: 0.018 - mae: 2.602 - mean_q: 3.132 - mean_eps: 0.426 - ale.lives: 2.191
#
# Interval 129 (1280000 steps performed)
# 10000/10000 [==============================] - 629s 63ms/step - reward: 0.0185
# 13 episodes - episode_reward: 14.231 [3.000, 25.000] - loss: 0.019 - mae: 2.619 - mean_q: 3.151 - mean_eps: 0.422 - ale.lives: 2.224
#
# Interval 130 (1290000 steps performed)
# 10000/10000 [==============================] - 628s 63ms/step - reward: 0.0185
# 13 episodes - episode_reward: 13.923 [7.000, 24.000] - loss: 0.019 - mae: 2.634 - mean_q: 3.170 - mean_eps: 0.417 - ale.lives: 2.081
#
# Interval 131 (1300000 steps performed)
# 10000/10000 [==============================] - 621s 62ms/step - reward: 0.0199
# 12 episodes - episode_reward: 17.333 [10.000, 27.000] - loss: 0.018 - mae: 2.660 - mean_q: 3.203 - mean_eps: 0.413 - ale.lives: 2.061
#
# Interval 132 (1310000 steps performed)
# 10000/10000 [==============================] - 623s 62ms/step - reward: 0.0189
# 15 episodes - episode_reward: 12.267 [4.000, 21.000] - loss: 0.019 - mae: 2.687 - mean_q: 3.234 - mean_eps: 0.408 - ale.lives: 2.175
#
# Interval 133 (1320000 steps performed)
# 10000/10000 [==============================] - 628s 63ms/step - reward: 0.0209
# 13 episodes - episode_reward: 16.077 [5.000, 28.000] - loss: 0.019 - mae: 2.722 - mean_q: 3.277 - mean_eps: 0.404 - ale.lives: 1.952
#
# Interval 134 (1330000 steps performed)
# 10000/10000 [==============================] - 625s 62ms/step - reward: 0.0181
# 15 episodes - episode_reward: 12.467 [5.000, 31.000] - loss: 0.020 - mae: 2.737 - mean_q: 3.294 - mean_eps: 0.399 - ale.lives: 1.973
#
# Interval 135 (1340000 steps performed)
# 10000/10000 [==============================] - 619s 62ms/step - reward: 0.0213
# 13 episodes - episode_reward: 15.846 [6.000, 31.000] - loss: 0.019 - mae: 2.770 - mean_q: 3.335 - mean_eps: 0.395 - ale.lives: 2.056
#
# Interval 136 (1350000 steps performed)
# 10000/10000 [==============================] - 634s 63ms/step - reward: 0.0191
# 12 episodes - episode_reward: 15.583 [5.000, 23.000] - loss: 0.019 - mae: 2.784 - mean_q: 3.354 - mean_eps: 0.390 - ale.lives: 2.045
#
# Interval 137 (1360000 steps performed)
# 10000/10000 [==============================] - 636s 64ms/step - reward: 0.0174
# 14 episodes - episode_reward: 12.786 [6.000, 18.000] - loss: 0.020 - mae: 2.828 - mean_q: 3.406 - mean_eps: 0.386 - ale.lives: 1.980
#
# Interval 138 (1370000 steps performed)
# 10000/10000 [==============================] - 608s 61ms/step - reward: 0.0191
# 12 episodes - episode_reward: 15.917 [8.000, 31.000] - loss: 0.020 - mae: 2.814 - mean_q: 3.389 - mean_eps: 0.381 - ale.lives: 2.261
#
# Interval 139 (1380000 steps performed)
# 10000/10000 [==============================] - 632s 63ms/step - reward: 0.0200
# 14 episodes - episode_reward: 13.571 [5.000, 27.000] - loss: 0.019 - mae: 2.829 - mean_q: 3.405 - mean_eps: 0.377 - ale.lives: 2.113
#
# Interval 140 (1390000 steps performed)
# 10000/10000 [==============================] - 631s 63ms/step - reward: 0.0232
# 12 episodes - episode_reward: 20.083 [8.000, 34.000] - loss: 0.020 - mae: 2.855 - mean_q: 3.439 - mean_eps: 0.372 - ale.lives: 2.015
#
# Interval 141 (1400000 steps performed)
# 10000/10000 [==============================] - 621s 62ms/step - reward: 0.0217
# 12 episodes - episode_reward: 17.833 [11.000, 29.000] - loss: 0.021 - mae: 2.875 - mean_q: 3.461 - mean_eps: 0.368 - ale.lives: 1.903
#
# Interval 142 (1410000 steps performed)
# 10000/10000 [==============================] - 606s 61ms/step - reward: 0.0198
# 14 episodes - episode_reward: 14.714 [7.000, 25.000] - loss: 0.020 - mae: 2.885 - mean_q: 3.472 - mean_eps: 0.363 - ale.lives: 1.982
#
# Interval 143 (1420000 steps performed)
# 10000/10000 [==============================] - 628s 63ms/step - reward: 0.0185
# 13 episodes - episode_reward: 13.538 [8.000, 25.000] - loss: 0.020 - mae: 2.878 - mean_q: 3.462 - mean_eps: 0.359 - ale.lives: 2.004
#
# Interval 144 (1430000 steps performed)
# 10000/10000 [==============================] - 614s 61ms/step - reward: 0.0199
# 13 episodes - episode_reward: 15.385 [4.000, 30.000] - loss: 0.020 - mae: 2.898 - mean_q: 3.487 - mean_eps: 0.354 - ale.lives: 2.051
#
# Interval 145 (1440000 steps performed)
# 10000/10000 [==============================] - 628s 63ms/step - reward: 0.0193
# 15 episodes - episode_reward: 13.333 [4.000, 22.000] - loss: 0.020 - mae: 2.896 - mean_q: 3.486 - mean_eps: 0.350 - ale.lives: 1.996
#
# Interval 146 (1450000 steps performed)
# 10000/10000 [==============================] - 637s 64ms/step - reward: 0.0206
# 14 episodes - episode_reward: 14.929 [8.000, 22.000] - loss: 0.020 - mae: 2.905 - mean_q: 3.495 - mean_eps: 0.345 - ale.lives: 2.008
#
# Interval 147 (1460000 steps performed)
# 10000/10000 [==============================] - 627s 63ms/step - reward: 0.0227
# 11 episodes - episode_reward: 20.000 [10.000, 28.000] - loss: 0.020 - mae: 2.914 - mean_q: 3.506 - mean_eps: 0.341 - ale.lives: 2.241
#
# Interval 148 (1470000 steps performed)
# 10000/10000 [==============================] - 628s 63ms/step - reward: 0.0183
# 13 episodes - episode_reward: 13.385 [4.000, 29.000] - loss: 0.020 - mae: 2.912 - mean_q: 3.502 - mean_eps: 0.336 - ale.lives: 1.979
#
# Interval 149 (1480000 steps performed)
# 10000/10000 [==============================] - 634s 63ms/step - reward: 0.0185
# 13 episodes - episode_reward: 14.308 [10.000, 20.000] - loss: 0.020 - mae: 2.939 - mean_q: 3.534 - mean_eps: 0.332 - ale.lives: 2.066
#
# Interval 150 (1490000 steps performed)
# 10000/10000 [==============================] - 627s 63ms/step - reward: 0.0213
# 15 episodes - episode_reward: 15.133 [8.000, 28.000] - loss: 0.019 - mae: 2.954 - mean_q: 3.553 - mean_eps: 0.327 - ale.lives: 2.100
#
# Interval 151 (1500000 steps performed)
# 10000/10000 [==============================] - 621s 62ms/step - reward: 0.0218
# 11 episodes - episode_reward: 17.545 [5.000, 35.000] - loss: 0.019 - mae: 2.962 - mean_q: 3.562 - mean_eps: 0.323 - ale.lives: 1.980
#
# Interval 152 (1510000 steps performed)
# 10000/10000 [==============================] - 622s 62ms/step - reward: 0.0214
# 12 episodes - episode_reward: 18.917 [8.000, 29.000] - loss: 0.019 - mae: 2.963 - mean_q: 3.562 - mean_eps: 0.318 - ale.lives: 2.234
#
# Interval 153 (1520000 steps performed)
# 10000/10000 [==============================] - 633s 63ms/step - reward: 0.0212
# 13 episodes - episode_reward: 15.846 [8.000, 27.000] - loss: 0.019 - mae: 2.976 - mean_q: 3.577 - mean_eps: 0.314 - ale.lives: 2.015
#
# Interval 154 (1530000 steps performed)
# 10000/10000 [==============================] - 631s 63ms/step - reward: 0.0195
# 13 episodes - episode_reward: 15.462 [8.000, 27.000] - loss: 0.019 - mae: 2.975 - mean_q: 3.576 - mean_eps: 0.309 - ale.lives: 1.993
#
# Interval 155 (1540000 steps performed)
# 10000/10000 [==============================] - 628s 63ms/step - reward: 0.0194
# 13 episodes - episode_reward: 15.923 [8.000, 31.000] - loss: 0.020 - mae: 2.994 - mean_q: 3.598 - mean_eps: 0.305 - ale.lives: 1.858
#
# Interval 156 (1550000 steps performed)
# 10000/10000 [==============================] - 614s 61ms/step - reward: 0.0201
# 10 episodes - episode_reward: 18.700 [13.000, 35.000] - loss: 0.019 - mae: 2.991 - mean_q: 3.595 - mean_eps: 0.300 - ale.lives: 2.052
#
# Interval 157 (1560000 steps performed)
# 10000/10000 [==============================] - 624s 62ms/step - reward: 0.0173
# 12 episodes - episode_reward: 14.917 [6.000, 22.000] - loss: 0.019 - mae: 3.019 - mean_q: 3.626 - mean_eps: 0.296 - ale.lives: 2.065
#
# Interval 158 (1570000 steps performed)
# 10000/10000 [==============================] - 626s 63ms/step - reward: 0.0200
# 11 episodes - episode_reward: 18.000 [9.000, 31.000] - loss: 0.019 - mae: 2.993 - mean_q: 3.594 - mean_eps: 0.291 - ale.lives: 2.160
#
# Interval 159 (1580000 steps performed)
# 10000/10000 [==============================] - 621s 62ms/step - reward: 0.0196
# 14 episodes - episode_reward: 14.714 [5.000, 23.000] - loss: 0.020 - mae: 2.985 - mean_q: 3.584 - mean_eps: 0.287 - ale.lives: 2.219
#
# Interval 160 (1590000 steps performed)
# 10000/10000 [==============================] - 628s 63ms/step - reward: 0.0205
# 11 episodes - episode_reward: 16.273 [6.000, 29.000] - loss: 0.020 - mae: 2.980 - mean_q: 3.579 - mean_eps: 0.282 - ale.lives: 2.226
#
# Interval 161 (1600000 steps performed)
# 10000/10000 [==============================] - 627s 63ms/step - reward: 0.0205
# 9 episodes - episode_reward: 23.444 [13.000, 33.000] - loss: 0.019 - mae: 2.950 - mean_q: 3.543 - mean_eps: 0.278 - ale.lives: 2.006
#
# Interval 162 (1610000 steps performed)
# 10000/10000 [==============================] - 628s 63ms/step - reward: 0.0187
# 13 episodes - episode_reward: 15.462 [8.000, 21.000] - loss: 0.020 - mae: 2.947 - mean_q: 3.540 - mean_eps: 0.273 - ale.lives: 2.298
#
# Interval 163 (1620000 steps performed)
# 10000/10000 [==============================] - 623s 62ms/step - reward: 0.0193
# 11 episodes - episode_reward: 15.818 [8.000, 22.000] - loss: 0.019 - mae: 2.958 - mean_q: 3.553 - mean_eps: 0.269 - ale.lives: 2.279
#
# Interval 164 (1630000 steps performed)
# 10000/10000 [==============================] - 636s 64ms/step - reward: 0.0184
# 12 episodes - episode_reward: 17.417 [9.000, 27.000] - loss: 0.019 - mae: 2.948 - mean_q: 3.541 - mean_eps: 0.264 - ale.lives: 2.128
#
# Interval 165 (1640000 steps performed)
# 10000/10000 [==============================] - 621s 62ms/step - reward: 0.0177
# 12 episodes - episode_reward: 14.000 [6.000, 23.000] - loss: 0.020 - mae: 2.964 - mean_q: 3.559 - mean_eps: 0.260 - ale.lives: 2.111
#
# Interval 166 (1650000 steps performed)
# 10000/10000 [==============================] - 628s 63ms/step - reward: 0.0203
# 12 episodes - episode_reward: 17.333 [7.000, 31.000] - loss: 0.020 - mae: 2.950 - mean_q: 3.543 - mean_eps: 0.255 - ale.lives: 2.083
#
# Interval 167 (1660000 steps performed)
# 10000/10000 [==============================] - 632s 63ms/step - reward: 0.0199
# 9 episodes - episode_reward: 19.444 [12.000, 26.000] - loss: 0.020 - mae: 2.937 - mean_q: 3.529 - mean_eps: 0.251 - ale.lives: 2.133
#
# Interval 168 (1670000 steps performed)
# 10000/10000 [==============================] - 631s 63ms/step - reward: 0.0197
# 10 episodes - episode_reward: 22.200 [13.000, 29.000] - loss: 0.019 - mae: 2.933 - mean_q: 3.524 - mean_eps: 0.246 - ale.lives: 2.085
#
# Interval 169 (1680000 steps performed)
# 10000/10000 [==============================] - 633s 63ms/step - reward: 0.0171
# 11 episodes - episode_reward: 15.364 [9.000, 25.000] - loss: 0.018 - mae: 2.930 - mean_q: 3.520 - mean_eps: 0.242 - ale.lives: 2.193
#
# Interval 170 (1690000 steps performed)
# 10000/10000 [==============================] - 641s 64ms/step - reward: 0.0190
# 10 episodes - episode_reward: 19.400 [9.000, 32.000] - loss: 0.018 - mae: 2.925 - mean_q: 3.514 - mean_eps: 0.237 - ale.lives: 2.275
#
# Interval 171 (1700000 steps performed)
# 10000/10000 [==============================] - 628s 63ms/step - reward: 0.0176
# 10 episodes - episode_reward: 17.000 [5.000, 32.000] - loss: 0.018 - mae: 2.935 - mean_q: 3.525 - mean_eps: 0.233 - ale.lives: 2.191
#
# Interval 172 (1710000 steps performed)
# 10000/10000 [==============================] - 633s 63ms/step - reward: 0.0201
# 10 episodes - episode_reward: 18.800 [10.000, 30.000] - loss: 0.018 - mae: 2.925 - mean_q: 3.514 - mean_eps: 0.228 - ale.lives: 2.087
#
# Interval 173 (1720000 steps performed)
# 10000/10000 [==============================] - 621s 62ms/step - reward: 0.0189
# 12 episodes - episode_reward: 16.917 [4.000, 28.000] - loss: 0.018 - mae: 2.915 - mean_q: 3.501 - mean_eps: 0.224 - ale.lives: 2.159
#
# Interval 174 (1730000 steps performed)
# 10000/10000 [==============================] - 638s 64ms/step - reward: 0.0186
# 12 episodes - episode_reward: 15.250 [7.000, 23.000] - loss: 0.018 - mae: 2.903 - mean_q: 3.487 - mean_eps: 0.219 - ale.lives: 2.043
#
# Interval 175 (1740000 steps performed)
# 10000/10000 [==============================] - 632s 63ms/step - reward: 0.0194
# 11 episodes - episode_reward: 17.455 [9.000, 24.000] - loss: 0.019 - mae: 2.909 - mean_q: 3.493 - mean_eps: 0.215 - ale.lives: 2.108
#
# Interval 176 (1750000 steps performed)
# 10000/10000 [==============================] - 634s 63ms/step - reward: 0.0190
# 12 episodes - episode_reward: 15.750 [9.000, 22.000] - loss: 0.018 - mae: 2.910 - mean_q: 3.495 - mean_eps: 0.210 - ale.lives: 1.997
#
# Interval 177 (1760000 steps performed)
# 10000/10000 [==============================] - 643s 64ms/step - reward: 0.0195
# 11 episodes - episode_reward: 18.182 [10.000, 32.000] - loss: 0.018 - mae: 2.924 - mean_q: 3.513 - mean_eps: 0.206 - ale.lives: 2.110
#
# Interval 178 (1770000 steps performed)
# 10000/10000 [==============================] - 634s 63ms/step - reward: 0.0194
# 11 episodes - episode_reward: 17.455 [6.000, 28.000] - loss: 0.017 - mae: 2.915 - mean_q: 3.501 - mean_eps: 0.201 - ale.lives: 2.081
#
# Interval 179 (1780000 steps performed)
# 10000/10000 [==============================] - 641s 64ms/step - reward: 0.0203
# 11 episodes - episode_reward: 19.091 [9.000, 34.000] - loss: 0.018 - mae: 2.914 - mean_q: 3.501 - mean_eps: 0.197 - ale.lives: 2.026
#
# Interval 180 (1790000 steps performed)
# 10000/10000 [==============================] - 831s 83ms/step - reward: 0.0179
# 11 episodes - episode_reward: 14.727 [8.000, 28.000] - loss: 0.018 - mae: 2.907 - mean_q: 3.491 - mean_eps: 0.192 - ale.lives: 2.043
#
# Interval 181 (1800000 steps performed)
# 10000/10000 [==============================] - 784s 78ms/step - reward: 0.0198
# 12 episodes - episode_reward: 17.667 [4.000, 24.000] - loss: 0.018 - mae: 2.912 - mean_q: 3.499 - mean_eps: 0.188 - ale.lives: 2.082
#
# Interval 182 (1810000 steps performed)
#    65/10000 [..............................] - ETA: 10:10 - reward: 0.0154done, took 89885.579 seconds

# %%
##### Guardado de pesos
dqn.save_weights('dqn_spaceinvaders_weights.h5f', overwrite=True)

# %%
#Evaluación en modo test
scores = dqn.test(env, nb_episodes=10, visualize=True)
print("Media de recompensa:", np.mean(scores.history['episode_reward']))
# Out:
# Testing for 10 episodes ...
# Episode 1: reward: 23.000, steps: 845
# Episode 2: reward: 32.000, steps: 1148
# Episode 3: reward: 22.000, steps: 903
# Episode 4: reward: 13.000, steps: 627
# Episode 5: reward: 16.000, steps: 696
# Episode 6: reward: 18.000, steps: 712
# Episode 7: reward: 24.000, steps: 1248
# Episode 8: reward: 19.000, steps: 900
# Episode 9: reward: 23.000, steps: 964
# Episode 10: reward: 23.000, steps: 1110
# Media de recompensa: 21.3

# %%
#Evaluación en modo test
scores = dqn.test(env, nb_episodes=10, visualize=True)
print("Media de recompensa:", np.mean(scores.history['episode_reward']))

# %% [markdown]
# 3. Justificación de los parámetros seleccionados y de los resultados obtenidos

# %% [markdown]
# ---
