# %% [markdown]
# # Actividad - Proyecto práctico
#
#
# > La actividad se desarrollará en grupos pre-definidos de 2-3 alumnos. Se debe indicar los nombres en orden alfabético (de apellidos). Recordad que esta actividad se corresponde con un 30% de la nota final de la asignatura. Se debe entregar entregar el trabajo en la presente notebook.
# *   Alumno 1: Marta Castillo Galán
# *   Alumno 2: Unai Marín Etxebarria
# *   Alumno 3: Laura Molinos Mayo
# *   Alumno 4: Raúl Murillo Gallego

# %% [markdown]
# ---
# ## **PARTE 2**. Enunciado
#
# Consideraciones a tener en cuenta:
#
# - El entorno sobre el que trabajaremos será _SpaceInvaders-v0_ y el algoritmo que usaremos será _DQN_.
#
# - Para nuestro ejercicio, el requisito mínimo será alcanzado cuando el agente consiga una **media de recompensa por encima de 20 puntos en modo test**. Por ello, esta media de la recompensa se calculará a partir del código de test en la última celda del notebook.
#
# Este proyecto práctico consta de tres partes:
#
# 1.   Implementar la red neuronal que se usará en la solución
# 2.   Implementar las distintas piezas de la solución DQN
# 3.   Justificar la respuesta en relación a los resultados obtenidos
#
# **Rúbrica**: Se valorará la originalidad en la solución aportada, así como la capacidad de discutir los resultados de forma detallada. El requisito mínimo servirá para aprobar la actividad, bajo premisa de que la discusión del resultado sera apropiada.
#
# IMPORTANTE:
#
# * Si no se consigue una puntuación óptima, responder sobre la mejor puntuación obtenida.
# * Para entrenamientos largos, recordad que podéis usar checkpoints de vuestros modelos para retomar los entrenamientos. En este caso, recordad cambiar los parámetros adecuadamente (sobre todo los relacionados con el proceso de exploración).
# * Se deberá entregar unicamente el notebook y los pesos del mejor modelo en un fichero .zip, de forma organizada.
# * Cada alumno deberá de subir la solución de forma individual.

# %% [markdown]
# ---
# ## **PARTE 3**. Desarrollo y preguntas

# %% [markdown]
# #### Importar librerías

# %%
from __future__ import division

from PIL import Image
import numpy as np
import gym

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Activation, Flatten, Convolution2D, Permute, BatchNormalization, Dropout
from tensorflow.keras.optimizers import Adam
import tensorflow.keras.backend as K

from rl.agents.dqn import DQNAgent
from rl.policy import LinearAnnealedPolicy, BoltzmannQPolicy, EpsGreedyQPolicy
from rl.memory import SequentialMemory
from rl.core import Processor
from rl.callbacks import FileLogger, ModelIntervalCheckpoint

from tensorflow.keras.optimizers import RMSprop
import matplotlib.pyplot as plt

# %% [markdown]
# #### Configuración base

# %%
INPUT_SHAPE = (84, 84)
WINDOW_LENGTH = 4

env_name = 'SpaceInvaders-v0'
env = gym.make(env_name)

np.random.seed(123)
env.seed(123)
nb_actions = env.action_space.n

# %%
class AtariProcessor(Processor):
    def process_observation(self, observation):
        assert observation.ndim == 3  # (height, width, channel)
        img = Image.fromarray(observation)
        img = img.resize(INPUT_SHAPE).convert('L')
        processed_observation = np.array(img)
        assert processed_observation.shape == INPUT_SHAPE
        return processed_observation.astype('uint8')

    def process_state_batch(self, batch):
        processed_batch = batch.astype('float32') / 255.
        return processed_batch

    def process_reward(self, reward):
        return np.clip(reward, -1., 1.)

# %% [markdown]
# 1. Implementación de la red neuronal

# %%
def build_model(window_length, input_shape, nb_actions):
    model = Sequential()
    model.add(Permute((2, 3, 1), input_shape=(window_length,) + input_shape))  # (window, 84, 84) → (84, 84, window)
    model.add(Convolution2D(32, (8, 8), strides=(1, 1), activation='relu'))
    model.add(BatchNormalization())
    model.add(Convolution2D(64, (4, 4), strides=(1, 1), activation='relu'))
    model.add(BatchNormalization())
    model.add(Convolution2D(128, (2, 2), strides=(1, 1), activation='relu'))
    model.add(BatchNormalization())
    model.add(Flatten())
    model.add(Dense(128, activation='relu'))
    model.add(Dense(nb_actions, activation='linear'))
    return model

# %% [markdown]
# 2. Implementación de la solución DQN

# %%
# Preparamos memoria y política
memory = SequentialMemory(limit=1_000_000, window_length=WINDOW_LENGTH)
policy = LinearAnnealedPolicy(EpsGreedyQPolicy(),  
                              attr='eps',          
                              value_max=1.,       
                              value_min=0.05,       
                              value_test=0.05,      
                              nb_steps=2_000_000)  

# Creamos el modelo
model = build_model(WINDOW_LENGTH, INPUT_SHAPE, nb_actions)
print(model.summary())

# Creamos el procesador
processor = AtariProcessor()

#Creamos el agente
dqn = DQNAgent(model=model,
               nb_actions=nb_actions,
               policy=policy,
               memory=memory,
               processor=processor,
               nb_steps_warmup = 20_000,
               gamma=0.99,
               target_model_update=10_000,
               train_interval=5,
               delta_clip=1.0,
               enable_double_dqn=True,
               enable_dueling_network=True, dueling_type='max')

dqn.compile(Adam(learning_rate=0.001), metrics=['mae'])
# Out:
# WARNING:tensorflow:From C:\Users\laura\anaconda3\envs\miar_rl\lib\site-packages\tensorflow\python\keras\layers\normalization.py:534: _colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# permute (Permute)            (None, 84, 84, 4)         0
# _________________________________________________________________
# conv2d (Conv2D)              (None, 77, 77, 32)        8224
# _________________________________________________________________
# batch_normalization (BatchNo (None, 77, 77, 32)        128
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 74, 74, 64)        32832
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 74, 74, 64)        256
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 73, 73, 128)       32896
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 73, 73, 128)       512
# _________________________________________________________________
# flatten (Flatten)            (None, 682112)            0
# _________________________________________________________________
# dense (Dense)                (None, 128)               87310464
# _________________________________________________________________
# dense_1 (Dense)              (None, 6)                 774
# =================================================================
# Total params: 87,386,086
# Trainable params: 87,385,638
# Non-trainable params: 448
# _________________________________________________________________
# None

# %%
history=dqn.fit(env, nb_steps=200_000, visualize=False, verbose=1)
# Out:
# Training for 200000 steps ...
# Interval 1 (0 steps performed)
# C:\Users\laura\anaconda3\envs\miar_rl\lib\site-packages\tensorflow\python\keras\engine\training.py:2426: UserWarning: `Model.state_updates` will be removed in a future version. This property should not be used in TensorFlow 2.0, as `updates` are applied automatically.
#   warnings.warn('`Model.state_updates` will be removed in a future version. '
# 10000/10000 [==============================] - 135s 13ms/step - reward: 0.0123
# 15 episodes - episode_reward: 7.733 [4.000, 12.000] - ale.lives: 2.206
#
# Interval 2 (10000 steps performed)
# 10000/10000 [==============================] - 125s 13ms/step - reward: 0.0162
# 13 episodes - episode_reward: 12.462 [4.000, 29.000] - ale.lives: 2.057
#
# Interval 3 (20000 steps performed)
# 10000/10000 [==============================] - 619s 62ms/step - reward: 0.0137
# 16 episodes - episode_reward: 8.938 [3.000, 20.000] - loss: 1.442 - mae: 1.453 - mean_q: 1.572 - mean_eps: 0.988 - ale.lives: 2.087
#
# Interval 4 (30000 steps performed)
# 10000/10000 [==============================] - 606s 61ms/step - reward: 0.0163
# 14 episodes - episode_reward: 11.214 [5.000, 25.000] - loss: 0.008 - mae: 0.019 - mean_q: 0.025 - mean_eps: 0.983 - ale.lives: 2.072
#
# Interval 5 (40000 steps performed)
# 10000/10000 [==============================] - 606s 61ms/step - reward: 0.0153
# 12 episodes - episode_reward: 12.417 [8.000, 21.000] - loss: 0.007 - mae: 0.036 - mean_q: 0.046 - mean_eps: 0.979 - ale.lives: 2.173
#
# Interval 6 (50000 steps performed)
# 10000/10000 [==============================] - 603s 60ms/step - reward: 0.0122
# 15 episodes - episode_reward: 8.400 [4.000, 18.000] - loss: 0.007 - mae: 0.051 - mean_q: 0.065 - mean_eps: 0.974 - ale.lives: 2.172
#
# Interval 7 (60000 steps performed)
# 10000/10000 [==============================] - 635s 64ms/step - reward: 0.0141
# 15 episodes - episode_reward: 9.733 [3.000, 22.000] - loss: 0.007 - mae: 0.064 - mean_q: 0.079 - mean_eps: 0.969 - ale.lives: 2.124
#
# Interval 8 (70000 steps performed)
# 10000/10000 [==============================] - 658s 66ms/step - reward: 0.0137
# 16 episodes - episode_reward: 8.250 [4.000, 11.000] - loss: 0.007 - mae: 0.070 - mean_q: 0.087 - mean_eps: 0.964 - ale.lives: 2.056
#
# Interval 9 (80000 steps performed)
# 10000/10000 [==============================] - 617s 62ms/step - reward: 0.0142
# 14 episodes - episode_reward: 10.214 [5.000, 19.000] - loss: 0.007 - mae: 0.077 - mean_q: 0.096 - mean_eps: 0.960 - ale.lives: 2.166
#
# Interval 10 (90000 steps performed)
# 10000/10000 [==============================] - 604s 60ms/step - reward: 0.0148
# 15 episodes - episode_reward: 9.867 [1.000, 24.000] - loss: 0.007 - mae: 0.085 - mean_q: 0.104 - mean_eps: 0.955 - ale.lives: 2.069
#
# Interval 11 (100000 steps performed)
# 10000/10000 [==============================] - 606s 61ms/step - reward: 0.0139
# 13 episodes - episode_reward: 10.846 [3.000, 22.000] - loss: 0.007 - mae: 0.104 - mean_q: 0.128 - mean_eps: 0.950 - ale.lives: 2.051
#
# Interval 12 (110000 steps performed)
# 10000/10000 [==============================] - 602s 60ms/step - reward: 0.0141
# 14 episodes - episode_reward: 10.357 [4.000, 23.000] - loss: 0.007 - mae: 0.117 - mean_q: 0.143 - mean_eps: 0.945 - ale.lives: 2.115
#
# Interval 13 (120000 steps performed)
# 10000/10000 [==============================] - 604s 60ms/step - reward: 0.0154
# 14 episodes - episode_reward: 10.786 [5.000, 25.000] - loss: 0.007 - mae: 0.127 - mean_q: 0.155 - mean_eps: 0.941 - ale.lives: 2.057
#
# Interval 14 (130000 steps performed)
# 10000/10000 [==============================] - 611s 61ms/step - reward: 0.0146
# 15 episodes - episode_reward: 9.933 [5.000, 17.000] - loss: 0.007 - mae: 0.132 - mean_q: 0.161 - mean_eps: 0.936 - ale.lives: 2.046
#
# Interval 15 (140000 steps performed)
# 10000/10000 [==============================] - 607s 61ms/step - reward: 0.0148
# 14 episodes - episode_reward: 10.071 [7.000, 16.000] - loss: 0.007 - mae: 0.146 - mean_q: 0.178 - mean_eps: 0.931 - ale.lives: 2.093
#
# Interval 16 (150000 steps performed)
# 10000/10000 [==============================] - 602s 60ms/step - reward: 0.0140
# 15 episodes - episode_reward: 9.800 [3.000, 18.000] - loss: 0.007 - mae: 0.153 - mean_q: 0.186 - mean_eps: 0.926 - ale.lives: 2.087
#
# Interval 17 (160000 steps performed)
# 10000/10000 [==============================] - 619s 62ms/step - reward: 0.0142
# 11 episodes - episode_reward: 11.636 [3.000, 24.000] - loss: 0.007 - mae: 0.162 - mean_q: 0.198 - mean_eps: 0.922 - ale.lives: 2.024
#
# Interval 18 (170000 steps performed)
# 10000/10000 [==============================] - 665s 66ms/step - reward: 0.0142
# 15 episodes - episode_reward: 10.200 [3.000, 23.000] - loss: 0.007 - mae: 0.170 - mean_q: 0.207 - mean_eps: 0.917 - ale.lives: 2.018
#
# Interval 19 (180000 steps performed)
# 10000/10000 [==============================] - 636s 64ms/step - reward: 0.0138
# 13 episodes - episode_reward: 10.231 [4.000, 16.000] - loss: 0.007 - mae: 0.179 - mean_q: 0.218 - mean_eps: 0.912 - ale.lives: 2.067
#
# Interval 20 (190000 steps performed)
# 10000/10000 [==============================] - 628s 63ms/step - reward: 0.0141
# done, took 11389.694 seconds

# %%
# Obtener las métricas
rewards = history.history['episode_reward']
steps = history.history['nb_steps']

# Crear el gráfico
plt.plot(steps, rewards)
plt.xlabel('Steps')
plt.ylabel('Rewards')
plt.grid(True)
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
#Evaluación en modo test
scores = dqn.test(env, nb_episodes=20, visualize=False, verbose=2)
print("Media de recompensa:", np.mean(scores.history['episode_reward']))
# Out:
# Testing for 20 episodes ...
# C:\Users\laura\anaconda3\envs\miar_rl\lib\site-packages\tensorflow\python\keras\engine\training.py:2426: UserWarning: `Model.state_updates` will be removed in a future version. This property should not be used in TensorFlow 2.0, as `updates` are applied automatically.
#   warnings.warn('`Model.state_updates` will be removed in a future version. '
# Episode 1: reward: 0.000, steps: 502
# Episode 2: reward: 0.000, steps: 501
# Episode 3: reward: 0.000, steps: 508
# Episode 4: reward: 0.000, steps: 509
# Episode 5: reward: 0.000, steps: 506
# Episode 6: reward: 0.000, steps: 494
# Episode 7: reward: 0.000, steps: 500
# Episode 8: reward: 0.000, steps: 495
# Episode 9: reward: 0.000, steps: 494
# Episode 10: reward: 0.000, steps: 504
# Episode 11: reward: 0.000, steps: 497
# Episode 12: reward: 0.000, steps: 514
# Episode 13: reward: 0.000, steps: 511
# Episode 14: reward: 0.000, steps: 500
# Episode 15: reward: 0.000, steps: 501
# Episode 16: reward: 0.000, steps: 508
# Episode 17: reward: 0.000, steps: 506
# Episode 18: reward: 0.000, steps: 500
# Episode 19: reward: 0.000, steps: 517
# Episode 20: reward: 0.000, steps: 514
# Media de recompensa: 0.0

# %% [markdown]
# 3. Justificación de los parámetros seleccionados y de los resultados obtenidos

# %% [markdown]
# ---
